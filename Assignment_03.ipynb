# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Answer :
    1. Increases reusability of code.
    2. more readibility of code.
    3. decreases programmer effort as no need to write same logic again and again.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Answer :
    code inside the functions execcute only when the function is called.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def Function_name():
    pass

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a function consists the logic and code which we can use to achieve required results.
# def function_01():
#     pass

a function call is used to execute the code inside the function, without calling the function code will not execute.
# function_01()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
There can be only 1 global scopes but multiple local scopes(as much as required) in apython program.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
local scope variables will cease to exist(means there will be no reserved memory location for that variable) once the function execution ends.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
function returns a value after its execution using return keyword.Yes it is possible to return value in an expression as we can see in below example.

# %%
# example:
def a():
    return 2
ap = a()*2
ap
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
It will return None value with data type as NoneType.

# %%
def p():
    pass
a = p()
print(a)
# Out:
# None

# %%
type(p())
# Out:
# NoneType

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
in python it can be done using global keyword.

# %%
# example:

a = 1
def test():
    global a
    a = 2
    return a
test()
print(a)
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
It is NoneType

# %%
type(None)
# Out:
# NoneType

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
If there is any module with name areallyourpetsnamederic then it will import this module and we can use functionality comprised in the imported modules.

but if there is no module with this name we get ModuleNotFoundError.

# %%
import areallyourpetsnamederic
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 import areallyourpetsnamederic
#
# ModuleNotFoundError: No module named 'areallyourpetsnamederic'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import spam
spam.bacon()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
we can do Exception handling to avoid such cases, if we know where program can encounter the errors.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
try clause is used to check the code for exceptions where we might encounter run-time error/exception.

except clause is used to handle the exception which code inside try clause encounters, can print custom message or required info  for that exception.
